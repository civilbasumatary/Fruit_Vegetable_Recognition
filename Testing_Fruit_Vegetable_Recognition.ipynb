# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %% [markdown]
# # Test set Image Processing

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    '/content/drive/MyDrive/Fruit_Vegetable_Recognition/test',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(64, 64),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 359 files belonging to 36 classes.

# %% [markdown]
# # Loading Model

# %%
cnn = tf.keras.models.load_model('/content/trained_model.h5')

# %% [markdown]
# # Visualising and Performing Prediction on Single imag

# %%
#Test Image Visualization
import cv2
image_path = '/content/drive/MyDrive/Fruit_Vegetable_Recognition/test/corn/Image_1.jpg'
# Reading an image in default mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# # Testing Model

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(64,64))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 0s 413ms/step

# %%
print(predictions)
# Out:
# [[7.15457508e-03 1.12991547e-04 3.30914263e-05 2.41454924e-04
#   2.15132150e-05 1.41422061e-04 3.80847487e-04 2.78946500e-05
#   3.02467309e-03 9.32451129e-01 5.15398897e-05 1.95977686e-04
#   2.92364639e-05 4.17593983e-04 7.46090314e-04 5.54088037e-04
#   1.91765124e-04 6.09552371e-05 2.20801048e-05 4.80857259e-03
#   2.77460320e-04 2.65483304e-05 6.70718378e-04 4.95216984e-04
#   1.12792368e-04 3.51278170e-04 7.49328348e-04 1.04543258e-04
#   1.37750106e-03 7.30738800e-04 1.51242377e-04 1.45134469e-02
#   1.11092835e-04 6.51624985e-04 4.51597589e-05 2.89637633e-02]]

# %%
# test_set.class_names

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)
# Out:
# 9

# %%
# Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
#Single image Prediction
print("It's a {}".format(test_set.class_names[result_index]))
# Out:
# It's a corn
